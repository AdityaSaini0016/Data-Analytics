# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df=pd.read_csv("Chocolate Sales.csv")
df=df[0:20]
df
# Out:
#            Sales Person      Country              Product       Date  \
# 0        Jehu Rudeforth           UK      Mint Chip Choco  04-Jan-22
# 1           Van Tuxwell        India        85% Dark Bars  01-Aug-22
# 2          Gigi Bohling        India  Peanut Butter Cubes  07-Jul-22
# 3          Jan Morforth    Australia  Peanut Butter Cubes  27-Apr-22
# 4        Jehu Rudeforth           UK  Peanut Butter Cubes  24-Feb-22
# 5           Van Tuxwell        India   Smooth Sliky Salty  06-Jun-22
# 6            Oby Sorrel           UK      99% Dark & Pure  25-Jan-22
# 7       Gunar Cockshoot    Australia          After Nines  24-Mar-22
# 8        Jehu Rudeforth  New Zealand       50% Dark Bites  20-Apr-22
# 9           Brien Boise    Australia      99% Dark & Pure  04-Jul-22
# 10  Rafaelita Blaksland           UK   Smooth Sliky Salty  13-Jan-22
# 11         Barr Faughny          USA         Orange Choco  10-Mar-22
# 12       Mallorie Waber       Canada              Eclairs  13-Jan-22
# ...

# %%
g=df.groupby("Country")
g

# %%
for Country, Country_df in g:
    print(Country)
    print(Country_df)
# Out:
# Australia
#        Sales Person    Country              Product       Date  Amount  \
# 3      Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22   12726
# 7   Gunar Cockshoot  Australia          After Nines  24-Mar-22    3080
# 9       Brien Boise  Australia      99% Dark & Pure  04-Jul-22    2835
# 15   Beverie Moffet  Australia  Organic Choco Syrup  26-Jan-22    6790
#
#     Boxes Shipped
# 3             342
# 7              73
# 9             102
# 15            356
# Canada
#       Sales Person Country              Product       Date  Amount  \
# 12  Mallorie Waber  Canada              Eclairs  13-Jan-22    1442
# 16     Van Tuxwell  Canada  Organic Choco Syrup  14-Feb-22    4067
# 18  Beverie Moffet  Canada            Milk Bars  16-Feb-22    8799
#
#     Boxes Shipped
# 12            286
# 16             42
# 18            250
# India
#    Sales Person Country              Product       Date  Amount  Boxes Shipped
# ...

# %%
g.get_group('Australia')
# Out:
#        Sales Person    Country              Product       Date  Amount  \
# 3      Jan Morforth  Australia  Peanut Butter Cubes  27-Apr-22   12726
# 7   Gunar Cockshoot  Australia          After Nines  24-Mar-22    3080
# 9       Brien Boise  Australia      99% Dark & Pure  04-Jul-22    2835
# 15   Beverie Moffet  Australia  Organic Choco Syrup  26-Jan-22    6790
#
#     Boxes Shipped
# 3             342
# 7              73
# 9             102
# 15            356

# %%
g.max()
# Out:
#                     Sales Person              Product       Date  Amount  \
# Country
# Australia           Jan Morforth  Peanut Butter Cubes  27-Apr-22   12726
# Canada               Van Tuxwell  Organic Choco Syrup  16-Feb-22    8799
# India                Van Tuxwell   Smooth Sliky Salty  07-Jul-22    7896
# New Zealand       Marney O'Breen  Peanut Butter Cubes  28-Jul-22    8379
# UK           Rafaelita Blaksland   Smooth Sliky Salty  25-Jan-22   13685
# USA              Roddy Speechley   Smooth Sliky Salty  10-Mar-22    3703
#
#              Boxes Shipped
# Country
# Australia              356
# Canada                 286
# India                   94
# New Zealand            173
# UK                     184
# USA                    140

# %%
df['Amount']=df['Amount'].replace('[/$,]','',regex=True)
df['Amount']=pd.to_numeric(df['Amount'], errors='coerce')
df['Amount']=df['Amount'].fillna(0).astype(int)
df
# Out:
#            Sales Person      Country              Product       Date  Amount  \
# 0        Jehu Rudeforth           UK      Mint Chip Choco  04-Jan-22    5320
# 1           Van Tuxwell        India        85% Dark Bars  01-Aug-22    7896
# 2          Gigi Bohling        India  Peanut Butter Cubes  07-Jul-22    4501
# 3          Jan Morforth    Australia  Peanut Butter Cubes  27-Apr-22   12726
# 4        Jehu Rudeforth           UK  Peanut Butter Cubes  24-Feb-22   13685
# 5           Van Tuxwell        India   Smooth Sliky Salty  06-Jun-22    5376
# 6            Oby Sorrel           UK      99% Dark & Pure  25-Jan-22   13685
# 7       Gunar Cockshoot    Australia          After Nines  24-Mar-22    3080
# 8        Jehu Rudeforth  New Zealand       50% Dark Bites  20-Apr-22    3990
# 9           Brien Boise    Australia      99% Dark & Pure  04-Jul-22    2835
# 10  Rafaelita Blaksland           UK   Smooth Sliky Salty  13-Jan-22    4704
# ...

# %%
india_weather= pd.DataFrame({
    "city" : ["Mumbai","Noida","Delhi"],
    "temperature" : [28,32,36],
    "humidity" : [60,70,80]

})
us_weather=pd.DataFrame({
    "city" : ["New York","Chicago","Houston"],
    "temperature" : [25,30,35],
    "humidity" : [50,60,70]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  New York           25        50
# 1   Chicago           30        60
# 2   Houston           35        70

# %%
india_weather
# Out:
#      city  temperature  humidity
# 0  Mumbai           28        60
# 1   Noida           32        70
# 2   Delhi           36        80

# %%
df=pd.concat([india_weather,us_weather], ignore_index=True) # Concatenate the two dataframes
df
# Out:
#        city  temperature  humidity
# 0    Mumbai           28        60
# 1     Noida           32        70
# 2     Delhi           36        80
# 3  New York           25        50
# 4   Chicago           30        60
# 5   Houston           35        70

# %%
df=pd.concat([india_weather,us_weather], keys=["india","us"])
df
# Out:
#              city  temperature  humidity
# india 0    Mumbai           28        60
#       1     Noida           32        70
#       2     Delhi           36        80
# us    0  New York           25        50
#       1   Chicago           30        60
#       2   Houston           35        70

# %%
df.loc["us"]
# Out:
#        city  temperature  humidity
# 0  New York           25        50
# 1   Chicago           30        60
# 2   Houston           35        70

# %%
temprature_df = pd.DataFrame({
    "city":["mumbai","delhi","banglore"],
    "temprature" : [32,42,30]
}, index=[0,1,2])
temprature_df
# Out:
#        city  temprature
# 0    mumbai          32
# 1     delhi          42
# 2  banglore          30

# %%
windspeed_df = pd.DataFrame({
    'city' : ['delhi','mumbai'],
    'Wind Speed (mph)': [5,7]
}, index=[1,0])
windspeed_df
# Out:
#      city  Wind Speed (mph)
# 1   delhi                 5
# 0  mumbai                 7

# %%
df = pd.concat([temprature_df, windspeed_df], axis=1)
df
# Out:
#        city  temprature    city  Wind Speed (mph)
# 0    mumbai          32  mumbai               7.0
# 1     delhi          42   delhi               5.0
# 2  banglore          30     NaN               NaN

# %%
s= pd.Series(["humid","dry","Rain"], name="event")
s
# Out:
# 0    humid
# 1      dry
# 2     Rain
# Name: event, dtype: object

# %%
df = pd.concat([temprature_df, s],axis=1)
df
# Out:
#        city  temprature  event
# 0    mumbai          32  humid
# 1     delhi          42    dry
# 2  banglore          30   Rain
