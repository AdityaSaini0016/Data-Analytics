# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,74,85,42,64]

# %%
#plt.plot(x,y, 'gD') 
plt.plot(x,y, color="green", marker='D')

# %%
days = [1,2,3,4,5,6,7]
max_t= [50,51,52,53,40,41,42]
min_t= [43,45,42,52,38,33,34]
avg_t= [45,47,44,54,39,37,36]
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather')
plt.plot(days,max_t, label= 'max')
plt.plot(days,min_t, label='min')
plt.plot(days,avg_t, label='avg')

plt.legend()
